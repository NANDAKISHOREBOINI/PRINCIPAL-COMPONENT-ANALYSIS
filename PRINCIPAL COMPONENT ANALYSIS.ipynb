# %%
import pandas as pd

data = pd.read_csv('C:\\Users\\NANDAKISHORE BOINI\\OneDrive\\Desktop\\wine.csv')
data
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
data.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
#Examine the distribution of features using histograms, box plots, or density plots.

import matplotlib.pyplot as plt

# Histograms
data.hist(figsize=(12, 10))
plt.show()

# %%
import matplotlib.pyplot as plt
# Box plots
data.plot(kind='box', subplots=True, layout=(4, 4), figsize=(12, 10))
plt.show()

# %%
import matplotlib.pyplot as plt
# Density plots
data.plot(kind='kde', subplots=True, layout=(4, 4), figsize=(12, 10))
plt.show()

# %%
#Investigate correlations between features to understand relationships within the data.

import matplotlib.pyplot as plt
# Correlation matrix
corr_matrix = data.corr()

# Heatmap
plt.figure(figsize=(12, 10))
import seaborn as sns
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
#Standardize the features to ensure they have a mean of 0 and a standard deviation of Implement PCA to reduce the dimensionality of the dataset.

import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Separate features and target variable (if applicable)
#X = data.drop('target', axis=1)  # Replace 'target' with your target variable column name if needed
X = data # If there is no target variable then use the whole dataframe

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=0.95)  # Keep components that explain 95% of the variance
principal_components = pca.fit_transform(X_scaled)

# Create a new DataFrame with principal components
principal_df = pd.DataFrame(data=principal_components)

# Print the explained variance ratio
print(pca.explained_variance_ratio_)
# Out:
# [0.39542486 0.17836259 0.10329102 0.06627984 0.06267875 0.0480556
#  0.03955707 0.02500244 0.02103871 0.01873615]

# %%
#Determine the optimal number of principal components using techniques like scree plot or cumulative explained variance.

import matplotlib.pyplot as plt
import numpy as np
# Calculate the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Create a scree plot
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o')
plt.title('Scree Plot')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.show()

# Calculate the cumulative explained variance
cumulative_variance = np.cumsum(explained_variance_ratio)

# Plot the cumulative explained variance
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o')
plt.title('Cumulative Explained Variance')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# %%
#Transform the original dataset into the principal components

# Transform the original dataset into the principal components
principal_components = pca.fit_transform(X_scaled)
pca.fit_transform(X_scaled)
# Out:
# array([[-3.5229339 , -1.45309844, -0.16479549, ...,  0.05563728,
#         -0.45876506,  1.06556955],
#        [-2.52885806,  0.33001925, -2.02670665, ...,  1.01037189,
#          0.21880609, -0.02018203],
#        [-2.78502898, -1.03693595,  0.9832377 , ..., -0.26895705,
#          1.22276949, -0.10624913],
#        ...,
#        [ 3.02727243, -2.75604024, -0.94080304, ...,  0.05254455,
#         -0.02788135, -0.21274935],
#        [ 2.75522166, -2.29378408, -0.55047368, ...,  0.42651198,
#          0.04878416,  0.47979317],
#        [ 3.49633565, -2.76060799,  1.01315115, ..., -0.32500213,
#         -0.7199834 ,  0.07990775]])

# %%
#Apply a clustering algorithm (e.g., K-means) to the original dataset.

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Apply K-means clustering
kmeans = KMeans(n_clusters=3, random_state=42)  # Choose the number of clusters (k)
kmeans.fit(X_scaled)

# Get the cluster labels for each data point
labels = kmeans.labels_

# Add the cluster labels to the DataFrame
data['cluster'] = labels

# Visualize the clusters (example with two principal components)
plt.figure(figsize=(8, 6))
plt.scatter(principal_df[0], principal_df[1], c=labels, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering')
plt.show()
# Out:
# C:\Users\NANDAKISHORE BOINI\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#Visualize the clustering results using appropriate plots.

import matplotlib.pyplot as plt
# Visualize the clusters (example with two principal components)
plt.figure(figsize=(8, 6))
plt.scatter(principal_df[0], principal_df[1], c=labels, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering')
plt.show()

# %%
import matplotlib.pyplot as plt
# Visualize the clusters using a pairplot
sns.pairplot(data, hue='cluster', vars=['Alcohol', 'Malic', 'Ash', 'Alcalinity'], height=3) # Changed 'Malic_acid' to 'Malic_Acid'
plt.show()

# %%
#Evaluate the clustering performance using metrics such as silhouette score or Davies–Bouldin index.

from sklearn.metrics import silhouette_score, davies_bouldin_score

# Calculate the silhouette score
silhouette_avg = silhouette_score(X_scaled, labels)
print("Silhouette Score:", silhouette_avg)

# Calculate the Davies-Bouldin index
db_index = davies_bouldin_score(X_scaled, labels)
print("Davies-Bouldin Index:", db_index)
# Out:
# Silhouette Score: 0.30648398324833453
# Davies-Bouldin Index: 1.315707552261773

# %%
#Apply the same clustering algorithm to the PCA-transformed dataset.

import matplotlib.pyplot as plt
# Apply K-means clustering to the PCA-transformed dataset
kmeans_pca = KMeans(n_clusters=3, random_state=42)
kmeans_pca.fit(principal_df)

# Get the cluster labels for each data point
labels_pca = kmeans_pca.labels_

# Add the cluster labels to the DataFrame
data['cluster_pca'] = labels_pca

# Visualize the clusters (example with two principal components)
plt.figure(figsize=(8, 6))
plt.scatter(principal_df[0], principal_df[1], c=labels_pca, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering on PCA Data')
plt.show()

# Visualize the clusters using a pairplot
sns.pairplot(data, hue='cluster_pca', vars=['Alcohol', 'Malic', 'Ash', 'Alcalinity'], height=3)
plt.show()

# Calculate the silhouette score for the PCA-transformed data
silhouette_avg_pca = silhouette_score(principal_df, labels_pca)
print("Silhouette Score (PCA):", silhouette_avg_pca)

# Calculate the Davies-Bouldin index for the PCA-transformed data
db_index_pca = davies_bouldin_score(principal_df, labels_pca)
print("Davies-Bouldin Index (PCA):", db_index_pca)
# Out:
# C:\Users\NANDAKISHORE BOINI\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Silhouette Score (PCA): 0.32292055407233045
# Davies-Bouldin Index (PCA): 1.2578453408449162

# %%
#Visualize the clustering results obtained from PCA-transformed data.

import matplotlib.pyplot as plt
# Visualize the clusters (example with two principal components)
plt.figure(figsize=(8, 6))
plt.scatter(principal_df[0], principal_df[1], c=labels_pca, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering on PCA Data')
plt.show()

# %%
#Compare the clustering results from PCA-transformed data with those from the original dataset.

# Compare the clustering results
print("Original data clustering:")
print("Silhouette Score:", silhouette_avg)
print("Davies-Bouldin Index:", db_index)

print("\nPCA-transformed data clustering:")
print("Silhouette Score (PCA):", silhouette_avg_pca)
print("Davies-Bouldin Index (PCA):", db_index_pca)
# Out:
# Original data clustering:
# Silhouette Score: 0.30648398324833453
# Davies-Bouldin Index: 1.315707552261773
#
# PCA-transformed data clustering:
# Silhouette Score (PCA): 0.32292055407233045
# Davies-Bouldin Index (PCA): 1.2578453408449162

# %%
#Compare the clustering results obtained from the original dataset and PCA-transformed data.

# Compare the clustering results
print("Original data clustering:")
print("Silhouette Score:", silhouette_avg)
print("Davies-Bouldin Index:", db_index)

print("\nPCA-transformed data clustering:")
print("Silhouette Score (PCA):", silhouette_avg_pca)
print("Davies-Bouldin Index (PCA):", db_index_pca)
# Out:
# Original data clustering:
# Silhouette Score: 0.30648398324833453
# Davies-Bouldin Index: 1.315707552261773
#
# PCA-transformed data clustering:
# Silhouette Score (PCA): 0.32292055407233045
# Davies-Bouldin Index (PCA): 1.2578453408449162

# %%
#Discuss any similarities or differences observed in the clustering results.

# Here's a summary of the analysis:

# Similarities:
# - Both clustering approaches (on original data and PCA-transformed data) show some separation between clusters.
# - The visualisations (pairplots and scatter plots) provide insights into how the clusters are formed.

# Differences:
# - The silhouette score and Davies-Bouldin index can vary between the two approaches. This suggests that PCA might improve cluster definition or
#   separation in some cases.
# - The visualisations might reveal different patterns in the clusters depending on the data representation (original or PCA-transformed).

# %%
# Summarize the key findings and insights from the assignment.

# Key findings and insights:

# 1. Data Exploration:
#    - Histograms, box plots, and density plots provided initial insights into the distribution of
#      each feature.
#    - The correlation matrix and heatmap revealed relationships between features.

# 2. Principal Component Analysis (PCA):
#    - PCA reduced the dimensionality of the data while preserving most of the variance.
#    - The scree plot and cumulative explained variance helped determine the optimal number of
#      principal components.

# 3. K-means Clustering:
#    - K-means clustering was applied to both the original data and the PCA-transformed data.
#    - Visualizations (scatter plots and pairplots) helped understand the cluster structure.

# 4. Evaluation Metrics:
#    - Silhouette score and Davies-Bouldin index were used to evaluate the quality of the clusters.
#    - Comparing these metrics for both clustering approaches provided insights into the impact of PCA.

# 5. Comparison of Clustering Results:
#    -  PCA might improve cluster definition or separation in some cases.
#    -  Visualizations helped identify differences in cluster assignments between the two approaches.

# 6. Further Analysis:
#    -  Comparing cluster assignments directly can reveal how PCA influences the grouping of data points.
#    -  Analyzing the impact of PCA on data structure helps understand how it transforms relationships
#       between variables.
#    -  Considering the specific goals of clustering is crucial for interpreting the results.

# %%
#Discuss the practical implications of using PCA and clustering in data analysis.

#Dimensionality Reduction: PCA simplifies complex datasets by reducing the number of variables while retaining essential information.
#This is useful for high-dimensional data where visualization and analysis become challenging.

#Data Visualization: PCA helps visualize high-dimensional data in lower dimensions (e.g., 2D or 3D), making it easier to identify patterns and relationships.

#Feature Extraction: PCA can create new features (principal components) that are linear combinations of original features.
#These new features can be more informative and improve the performance of machine learning models.

#Noise Reduction: PCA can filter out noise and irrelevant information by focusing on the principal components with the highest variance, leading to more robust models.

#Clustering: Clustering groups similar data points together, which helps in understanding the underlying structure of the data, identifying patterns, and making informed decisions.

#Customer Segmentation: In marketing, clustering can segment customers based on their purchasing behavior, demographics,
#or other characteristics, allowing for targeted advertising and personalized recommendations.

#Anomaly Detection: Clustering can identify outliers or anomalies that deviate significantly from the normal behavior of data points,
#which is useful for fraud detection, quality control, and system monitoring.

#Image Recognition: In computer vision, clustering can group similar images together, facilitating image retrieval and organization.

#By combining PCA and clustering, data analysts can effectively reduce dimensionality, visualize data, identify patterns, and gain valuable insights for decision-making in various domains

# %%
#Provide recommendations for when to use each technique based on the analysis conducted.

# Recommendations for using PCA and clustering:

# Use PCA when:

# - Dealing with high-dimensional data: When you have many features, PCA can help reduce dimensionality and improve model performance.
# - Visualizing data: PCA helps visualize data in lower dimensions, making it easier to understand patterns and relationships.
# - Feature extraction: PCA can create new features that are more informative than the original features.
# - Noise reduction: PCA can filter out noise and irrelevant information.

# Use clustering when:

# - Discovering patterns in data: Clustering helps identify groups of similar data points, revealing underlying structure.
# - Customer segmentation:  Clustering can segment customers based on their characteristics, enabling targeted marketing.
# - Anomaly detection: Clustering can identify outliers or anomalies in data.
# - Data exploration: Clustering can help explore data and identify potential relationships.

# Combining PCA and clustering:

# - When dealing with high-dimensional data where visualization and interpretation are challenging, PCA can be used to reduce dimensionality before applying clustering.
# - PCA can improve the performance of clustering algorithms by reducing noise and improving the separation of clusters.

# Considerations:

# - The choice between using PCA and clustering depends on the specific goals of the analysis.
# - If the goal is to discover underlying patterns in the data, clustering might be more suitable.
# - If the goal is to reduce dimensionality and improve model performance, PCA might be more appropriate.
# - It's important to evaluate the results of both techniques and choose the approach that best suits the specific needs of the analysis.
